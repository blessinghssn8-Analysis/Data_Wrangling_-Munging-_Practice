# %% [markdown]
# INSTALLATION OF PYTHON LIBRARIES

# %%
#INSTALL GOOGLE DRIVE LIBRARIES
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing all neccesary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1dc32293-8564-453d-95d4-54e13fbbf5e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1dc32293-8564-453d-95d4-54e13fbbf5e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Chun_data = pd.read_csv('Customer Churn Dataset.csv')

# %%
Chun_data.head()
# Out:
#    CustomerID Churn  Churn_coded  MonthlyRevenue  MonthlyMinutes  \
# 0     3000002   Yes            1           24.00           219.0
# 1     3000010   Yes            1           16.99            10.0
# 2     3000014    No            2           38.00             8.0
# 3     3000022    No            2           82.28          1312.0
# 4     3000026   Yes            1           17.14             0.0
#
#    TotalRecurringCharge  DirectorAssistedCalls  OverageMinutes  RoamingCalls  \
# 0                  22.0                   0.25             0.0           0.0
# 1                  17.0                   0.00             0.0           0.0
# 2                  38.0                   0.00             0.0           0.0
# 3                  75.0                   1.24             0.0           0.0
# 4                  17.0                   0.00             0.0           0.0
#
#    PercChangeMinutes  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
# View dataset lower part
Chun_data.tail()
# Out:
#        CustomerID Churn  Churn_coded  MonthlyRevenue  MonthlyMinutes  \
# 51042     3399958   Yes            1             NaN             NaN
# 51043     3399974    No            2           95.17          1745.0
# 51044     3399978   Yes            1             NaN             NaN
# 51045     3399990    No            2             NaN             NaN
# 51046     3399994    No            2             NaN             NaN
#
#        TotalRecurringCharge  DirectorAssistedCalls  OverageMinutes  \
# 51042                   NaN                    NaN             NaN
# 51043                  85.0                   0.99            45.0
# 51044                   NaN                    NaN             NaN
# 51045                   NaN                    NaN             NaN
# 51046                   NaN                    NaN             NaN
#
#        RoamingCalls  PercChangeMinutes  ...  ReferralsMadeBySubscriber  \
# 51042           NaN                NaN  ...                          0
# ...

# %%
Chun_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 59 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   Churn                      51047 non-null  object
#  2   Churn_coded                51047 non-null  int64
#  3   MonthlyRevenue             50891 non-null  float64
#  4   MonthlyMinutes             50891 non-null  float64
#  5   TotalRecurringCharge       50891 non-null  float64
#  6   DirectorAssistedCalls      50891 non-null  float64
#  7   OverageMinutes             50891 non-null  float64
#  8   RoamingCalls               50891 non-null  float64
#  9   PercChangeMinutes          50680 non-null  float64
#  10  PercChangeRevenues         50680 non-null  float64
#  11  DroppedCalls               51047 non-null  float64
#  12  BlockedCalls               51047 non-null  float64
# ...

# %%
# Data Dimension
Chun_data.shape
# Out:
# (51047, 59)

# %%
# Missing values
Chun_data.isnull().sum()
# Out:
# CustomerID                     0
# Churn                          0
# Churn_coded                    0
# MonthlyRevenue               156
# MonthlyMinutes               156
# TotalRecurringCharge         156
# DirectorAssistedCalls        156
# OverageMinutes               156
# RoamingCalls                 156
# PercChangeMinutes            367
# PercChangeRevenues           367
# DroppedCalls                   0
# BlockedCalls                   0
# UnansweredCalls                0
# CustomerCareCalls              0
# ThreewayCalls                  0
# ReceivedCalls                  0
# OutboundCalls                  0
# InboundCalls                   0
# PeakCallsInOut                 0
# OffPeakCallsInOut              0
# DroppedBlockedCalls            0
# CallForwardingCalls            0
# CallWaitingCalls               0
# MonthsInService                0
# UniqueSubs                     0
# ActiveSubs                     0
# ServiceArea                   24
# ...

# %%
# create a copy of chun data
DS = Chun_data.copy()

# %%
# Remove records with missing values
DS.dropna(inplace=True)

# %%
# Data set shape
DS.shape
# Out:
# (49752, 59)

# %%
# Check missing values from dataset
DS.isnull().sum()
# Out:
# CustomerID                   0
# Churn                        0
# Churn_coded                  0
# MonthlyRevenue               0
# MonthlyMinutes               0
# TotalRecurringCharge         0
# DirectorAssistedCalls        0
# OverageMinutes               0
# RoamingCalls                 0
# PercChangeMinutes            0
# PercChangeRevenues           0
# DroppedCalls                 0
# BlockedCalls                 0
# UnansweredCalls              0
# CustomerCareCalls            0
# ThreewayCalls                0
# ReceivedCalls                0
# OutboundCalls                0
# InboundCalls                 0
# PeakCallsInOut               0
# OffPeakCallsInOut            0
# DroppedBlockedCalls          0
# CallForwardingCalls          0
# CallWaitingCalls             0
# MonthsInService              0
# UniqueSubs                   0
# ActiveSubs                   0
# ServiceArea                  0
# Handsets                     0
# HandsetModels                0
# ...

# %%
# Explore data type
DS.dtypes
# Out:
# CustomerID                     int64
# Churn                         object
# Churn_coded                    int64
# MonthlyRevenue               float64
# MonthlyMinutes               float64
# TotalRecurringCharge         float64
# DirectorAssistedCalls        float64
# OverageMinutes               float64
# RoamingCalls                 float64
# PercChangeMinutes            float64
# PercChangeRevenues           float64
# DroppedCalls                 float64
# BlockedCalls                 float64
# UnansweredCalls              float64
# CustomerCareCalls            float64
# ThreewayCalls                float64
# ReceivedCalls                float64
# OutboundCalls                float64
# InboundCalls                 float64
# PeakCallsInOut               float64
# OffPeakCallsInOut            float64
# DroppedBlockedCalls          float64
# CallForwardingCalls          float64
# CallWaitingCalls             float64
# MonthsInService                int64
# ...

# %%
DS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49752 entries, 0 to 51043
# Data columns (total 59 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 49752 non-null  int64
#  1   Churn                      49752 non-null  object
#  2   Churn_coded                49752 non-null  int64
#  3   MonthlyRevenue             49752 non-null  float64
#  4   MonthlyMinutes             49752 non-null  float64
#  5   TotalRecurringCharge       49752 non-null  float64
#  6   DirectorAssistedCalls      49752 non-null  float64
#  7   OverageMinutes             49752 non-null  float64
#  8   RoamingCalls               49752 non-null  float64
#  9   PercChangeMinutes          49752 non-null  float64
#  10  PercChangeRevenues         49752 non-null  float64
#  11  DroppedCalls               49752 non-null  float64
#  12  BlockedCalls               49752 non-null  float64
# ...

# %% [markdown]
# Exploratory data analysis- Descriptive Statistical analysis of numeric

# %%
# Numeric var
DS.columns
# Out:
# Index(['CustomerID', 'Churn', 'Churn_coded', 'MonthlyRevenue',
#        'MonthlyMinutes', 'TotalRecurringCharge', 'DirectorAssistedCalls',
#        'OverageMinutes', 'RoamingCalls', 'PercChangeMinutes',
#        'PercChangeRevenues', 'DroppedCalls', 'BlockedCalls', 'UnansweredCalls',
#        'CustomerCareCalls', 'ThreewayCalls', 'ReceivedCalls', 'OutboundCalls',
#        'InboundCalls', 'PeakCallsInOut', 'OffPeakCallsInOut',
#        'DroppedBlockedCalls', 'CallForwardingCalls', 'CallWaitingCalls',
#        'MonthsInService', 'UniqueSubs', 'ActiveSubs', 'ServiceArea',
#        'Handsets', 'HandsetModels', 'CurrentEquipmentDays', 'AgeHH1', 'AgeHH2',
#        'ChildrenInHH', 'HandsetRefurbished', 'HandsetWebCapable', 'TruckOwner',
#        'RVOwner', 'Homeownership', 'BuysViaMailOrder', 'RespondsToMailOffers',
#        'OptOutMailings', 'NonUSTravel', 'OwnsComputer', 'HasCreditCard',
#        'RetentionCalls', 'RetentionOffersAccepted', 'NewCellphoneUser',
# ...

# %%
DS.describe()
# Out:
#          CustomerID   Churn_coded  MonthlyRevenue  MonthlyMinutes  \
# count  4.975200e+04  49752.000000    49752.000000    49752.000000
# mean   3.200958e+06      1.713680       58.717374      525.021466
# std    1.164694e+05      0.452045       44.317244      528.510155
# min    3.000002e+06      1.000000       -6.170000        0.000000
# 25%    3.100094e+06      1.000000       33.610000      158.000000
# 50%    3.200144e+06      2.000000       48.380000      366.000000
# 75%    3.303643e+06      2.000000       70.910000      722.000000
# max    3.399974e+06      2.000000     1223.380000     7359.000000
#
#        TotalRecurringCharge  ...  RetentionCalls  RetentionOffersAccepted  \
# count          49752.000000  ...    49752.000000             49752.000000
# mean              46.834961  ...        0.035496                 0.018331
# std               23.759492  ...        0.201964                 0.142854
# min               -6.000000  ...        0.000000                 0.000000
# ...

# %%
Numeric_Variables = DS[['MonthlyRevenue','MonthlyMinutes','TotalRecurringCharge','DirectorAssistedCalls','OverageMinutes','RoamingCalls','PercChangeMinutes','PercChangeRevenues','DroppedCalls','BlockedCalls','UnansweredCalls','CustomerCareCalls','ThreewayCalls','ReceivedCalls','OutboundCalls','InboundCalls','PeakCallsInOut','OffPeakCallsInOut','DroppedBlockedCalls','CallForwardingCalls','CallWaitingCalls','MonthsInService','UniqueSubs','ActiveSubs','CurrentEquipmentDays','AgeHH1','AgeHH2','ReferralsMadeBySubscriber','AdjustmentsToCreditRating']]
Numeric_Variables.describe().T
# Out:
#                              count        mean         std      min     25%  \
# MonthlyRevenue             49752.0   58.717374   44.317244    -6.17   33.61
# MonthlyMinutes             49752.0  525.021466  528.510155     0.00  158.00
# TotalRecurringCharge       49752.0   46.834961   23.759492    -6.00   30.00
# DirectorAssistedCalls      49752.0    0.891841    2.224725     0.00    0.00
# OverageMinutes             49752.0   39.754040   96.091606     0.00    0.00
# RoamingCalls               49752.0    1.226327    9.848360     0.00    0.00
# PercChangeMinutes          49752.0  -11.656175  255.858193 -3875.00  -83.00
# PercChangeRevenues         49752.0   -1.175937   39.392124 -1107.70   -7.00
# DroppedCalls               49752.0    6.010556    9.036653     0.00    0.70
# BlockedCalls               49752.0    4.077814   10.836468     0.00    0.00
# UnansweredCalls            49752.0   28.290957   38.860429     0.00    5.30
# ...

# %%
# Exploratory data analysis
#Frequency distrribution
print(DS.Churn.value_counts())
# Out:
# Churn
# No     35507
# Yes    14245
# Name: count, dtype: int64

# %%
#frequency distribution of Service Area
print(DS.ServiceArea.value_counts())
# Out:
# ServiceArea
# NYCBRO917    1646
# DALDAL214    1479
# HOUHOU281    1471
# NYCMAN917    1156
# DALFTW817     771
#              ...
# SANROM956       1
# INDCRA765       1
# SEWSUN509       1
# ATLDBL478       1
# NCRDNN910       1
# Name: count, Length: 743, dtype: int64

# %%
#frequency distribution of churn value
print(DS.Churn.value_counts())
# Out:
# Churn
# No     35507
# Yes    14245
# Name: count, dtype: int64

# %%
print(DS.ChildrenInHH.value_counts())
# Out:
# ChildrenInHH
# No     37483
# Yes    12269
# Name: count, dtype: int64

# %%
print(DS.HandsetRefurbished.value_counts())
# Out:
# HandsetRefurbished
# No     42852
# Yes     6900
# Name: count, dtype: int64

# %%
print(DS.HandsetWebCapable.value_counts())
# Out:
# HandsetWebCapable
# Yes    44905
# No      4847
# Name: count, dtype: int64

# %%
print(DS.HandsetWebCapable.value_counts())
# Out:
# HandsetWebCapable
# Yes    44905
# No      4847
# Name: count, dtype: int64

# %%
print(DS.RVOwner.value_counts())
# Out:
# RVOwner
# No     45619
# Yes     4133
# Name: count, dtype: int64

# %%
print(DS.Homeownership.value_counts())
# Out:
# Homeownership
# Known      33725
# Unknown    16027
# Name: count, dtype: int64

# %%
print(DS.BuysViaMailOrder.value_counts())
# Out:
# BuysViaMailOrder
# No     31432
# Yes    18320
# Name: count, dtype: int64

# %%
print(DS.RespondsToMailOffers.value_counts())
# Out:
# RespondsToMailOffers
# No     30667
# Yes    19085
# Name: count, dtype: int64

# %%
print(DS.OptOutMailings.value_counts())
# Out:
# OptOutMailings
# No     49006
# Yes      746
# Name: count, dtype: int64

# %%
print(DS.NonUSTravel.value_counts())
# Out:
# NonUSTravel
# No     46896
# Yes     2856
# Name: count, dtype: int64

# %%
print(DS.OwnsComputer.value_counts())
# Out:
# OwnsComputer
# No     40368
# Yes     9384
# Name: count, dtype: int64

# %%
print(DS.HasCreditCard.value_counts())
# Out:
# HasCreditCard
# Yes    34241
# No     15511
# Name: count, dtype: int64

# %%
print(DS.RetentionCalls.value_counts())
# Out:
# RetentionCalls
# 0    48131
# 1     1492
# 2      115
# 3       12
# 4        2
# Name: count, dtype: int64

# %%
print(DS.RetentionOffersAccepted.value_counts())
# Out:
# RetentionOffersAccepted
# 0    48892
# 1      816
# 2       36
# 3        8
# Name: count, dtype: int64

# %%
print(DS.NotNewCellphoneUser.value_counts())
# Out:
# NotNewCellphoneUser
# No     42877
# Yes     6875
# Name: count, dtype: int64

# %%
print(DS.ReferralsMadeBySubscriber.value_counts())
# Out:
# ReferralsMadeBySubscriber
# 0     47426
# 1      2190
# 2        98
# 3        21
# 4         5
# 6         4
# 7         2
# 5         2
# 16        1
# 11        1
# 8         1
# 9         1
# Name: count, dtype: int64

# %%
print(DS.IncomeGroup.value_counts())
# Out:
# IncomeGroup
# 0    11829
# 6     9548
# 7     5831
# 9     5508
# 5     4220
# 4     4033
# 3     2970
# 8     2603
# 1     2021
# 2     1189
# Name: count, dtype: int64

# %%
print(DS.OwnsMotorcycle.value_counts())
# Out:
# OwnsMotorcycle
# No     49078
# Yes      674
# Name: count, dtype: int64

# %%
print(DS.MadeCallToRetentionTeam.value_counts())
# Out:
# MadeCallToRetentionTeam
# No     48131
# Yes     1621
# Name: count, dtype: int64

# %%
print(DS.CreditRating.value_counts())
# Out:
# CreditRating
# 2-High       18692
# 1-Highest     8368
# 3-Good        8221
# 5-Low         6320
# 4-Medium      5227
# 7-Lowest      2049
# 6-VeryLow      875
# Name: count, dtype: int64

# %%
print(DS.PrizmCode.value_counts())
# Out:
# PrizmCode
# Other       23820
# Suburban    16049
# Town         7494
# Rural        2389
# Name: count, dtype: int64

# %%
print(DS.Occupation.value_counts())
# Out:
# Occupation
# Other           36453
# Professional     8681
# Crafts           1507
# Clerical          979
# Self              872
# Retired           726
# Student           377
# Homemaker         157
# Name: count, dtype: int64

# %%
print(DS.MaritalStatus.value_counts())
# Out:
# MaritalStatus
# Unknown    18649
# Yes        18506
# No         12597
# Name: count, dtype: int64

# %% [markdown]
# ## ***VISUALISATION***

# %%
plt.figure(figsize=(3,3))
sns.countplot(x = 'Churn', data=DS)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
# visualize Churn using pie chart
churn_counts = DS['Churn'].value_counts()
plt.figure(figsize=(4,4))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Customer Churn Distribution')
plt.show()
